# %% [markdown]
# <a href="https://colab.research.google.com/github/MxCvlibr/mlfl-train/blob/main/mlfl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os

path = "/content/gdrive/My Drive"
os.chdir(path)

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15118, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 15118 (delta 19), reused 34 (delta 15), pack-reused 15073
# Receiving objects: 100% (15118/15118), 13.49 MiB | 9.05 MiB/s, done.
# Resolving deltas: 100% (10265/10265), done.
# Checking out files: 100% (2032/2032), done.

# %%
# %cd darknet/
# !ls
# Out:
# /content/gdrive/My Drive/darknet
# 3rdparty		darknet_video.py       results
# backup			data		       scripts
# build			image_yolov3.sh        src
# build.ps1		image_yolov4.sh        train.log
# cfg			include		       train.txt
# chart.png		json_mjpeg_streams.sh  valid.txt
# chart_yolo-custom.png	LICENSE		       vcpkg.json
# cmake			Makefile	       video_yolov3.sh
# CMakeLists.txt		net_cam_v3.sh	       video_yolov4.sh
# darknet			net_cam_v4.sh	       yolo-custom.cfg
# darknet53.conv.74	obj		       yolo-custom_last.weights
# DarknetConfig.cmake.in	obj.data	       yolov3.cfg
# darknet_images.py	obj.names
# darknet.py		README.md

# %%
# !make

# %%
# !ls
# Out:
# 3rdparty	       DarknetConfig.cmake.in  LICENSE	      scripts
# backup		       darknet_images.py       Makefile       src
# build		       darknet.py	       net_cam_v3.sh  train.txt
# build.ps1	       darknet_video.py        net_cam_v4.sh  valid.txt
# cfg		       data		       obj	      vcpkg.json
# chart_yolo-custom.png  image_yolov3.sh	       obj.data       video_yolov3.sh
# cmake		       image_yolov4.sh	       obj.names      video_yolov4.sh
# CMakeLists.txt	       include		       README.md      yolo-custom.cfg
# darknet		       json_mjpeg_streams.sh   results	      yolov3.cfg

# %%
# import glob2
# import numpy as np

# all_files = []
# for ext in ["*.png", "*.jpeg", "*.jpg"]:
#   images = glob2.glob(os.path.join("../train_data/", ext))
#   all_files += images

# rand_idx = np.random.randint(0, len(all_files), 20)

# # Create train.txt
# with open("train.txt", "w") as f:
#   for idx in np.arange(len(all_files)):
#     # if idx not in rand_idx:
#     f.write(all_files[idx]+'\n')

# # Create valid.txt
# with open("valid.txt", "w") as f:
#   for idx in np.arange(len(all_files)):
#     if idx in rand_idx:
#       f.write(all_files[idx]+'\n')

# %%
# !echo batman > obj.names
# !echo flash >> obj.names
# !echo ironman >> obj.names
# !echo spiderman >> obj.names
# !echo thor >> obj.names

# %%
# !echo classes=5 > obj.data
# !echo train=train.txt >> obj.data
# !echo valid=test.txt >> obj.data
# !echo names=obj.names >> obj.data
# !echo backup=backup >> obj.data

# %%
#!cp cfg/yolov3.cfg yolo-custom.cfg
# %cd gdrive/darknet
# !ls
# Out:
# 3rdparty	       DarknetConfig.cmake.in  Makefile       train.log
# backup		       darknet_images.py       net_cam_v3.sh  train.txt
# build		       darknet.py	       net_cam_v4.sh  valid.txt
# build.ps1	       darknet_video.py        obj	      vcpkg.json
# cfg		       data		       obj.data       video_yolov3.sh
# chart_yolo-custom.png  image_yolov3.sh	       obj.names      video_yolov4.sh
# cmake		       image_yolov4.sh	       README.md      yolo-custom.cfg
# CMakeLists.txt	       include		       results	      yolov3.cfg
# darknet		       json_mjpeg_streams.sh   scripts
# darknet53.conv.74      LICENSE		       src

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-06-24 05:02:54--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  55.7MB/s    in 2.8s
#
# 2021-06-24 05:02:57 (55.7 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
#asdfasasdfasdfasdfasdfdf sadfs sdf sadf as jasdf sdf asdf asdfsd
# !chmod +x ./darknet

# %%
# !./darknet detector train obj.data yolo-custom.cfg yolo-custom_last.weights -dont_show -map -ext_output < train.txt > result.txt
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
# ...
